# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Data

# %%
df = pd.read_csv("/Users/godfather_101/Downloads/Heart_Disease/heart.csv")
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thall     0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %% [markdown]
# ### Data Cleaning

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df.plot(kind="box",figsize=(10,10))
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
sns.scatterplot(x=df["age"],y=df["chol"],hue=df["sex"])
plt.show()

# %%
sns.barplot(y=df["oldpeak"],x=df["output"],hue=df["cp"])
plt.show()

# %%
sns.barplot(x=df["output"],y=df["chol"],hue=df["thall"])
plt.show()

# %%
cat_data = []
for col in df.columns:
    if df[col].nunique() <=5:
        cat_data.append(col)

# %%
for i,col in enumerate(cat_data,start=1):
    plt.subplot(3,3,i)
    df[col].value_counts().plot(kind="bar",figsize=(15,10))

plt.tight_layout()
plt.show()

# %%
for i,col in enumerate(cat_data,start=1):
    plt.subplot(3,3,i)
    df[col].value_counts().plot(kind="hist",figsize=(15,10))

plt.tight_layout()
plt.show()

# %%
for i,col in enumerate(cat_data,start=1):
    plt.subplot(3,3,i)
    df[col].value_counts().plot(kind="box",figsize=(15,10))

plt.tight_layout()
plt.show()

# %%
for i,col in enumerate(cat_data,start=1):
    plt.subplot(3,3,i)
    df[col].value_counts().plot(kind="kde",figsize=(15,10))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
x = df.drop(["output"],axis=1)
y = df["output"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,yategori_train,y_test = train_test_split(x,y,test_size=.2,random_state=2,shuffle=True)

# %% [markdown]
# ### Model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.8305785123966942

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import mean_squared_error,accuracy_score,confusion_matrix
print("Accuracy :",accuracy_score(y_pred,y_test))
print("Mean_squared_error :",mean_squared_error(y_pred,y_test))
# Out:
# Accuracy : 0.9016393442622951
# Mean_squared_error : 0.09836065573770492

# %%
cm = confusion_matrix(y_pred,y_test)
sns.heatmap(cm,annot=True)
plt.show()

# %%
import joblib
joblib.dump(model,"Model-heart_disaese")
# Out:
# ['Model-heart_disaese']
